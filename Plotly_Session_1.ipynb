# %% [markdown]
# ### About Plotly
#
# Plotly is a Data Viz library by the company Plotly based out of Canada with support in languages such as Python, Js, Julia etc.
#
# #### Advantages
#
# - Multi language support
# - Lot's of graphs
# - Interactive plots
# - Beautiful plots
#
# Does not work with live data streams. Dash can be explored for that.

# %% [markdown]
# ### The Plotly Roadmap
#
# - Plotly Go
# - Plotly Express
# - Dash

# %% [markdown]
# ### Working with Plotly Go

# %%
# import the libraries
import plotly.graph_objects as go
import numpy as np
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt

# %%
# import datasets
tips = px.data.tips()
iris = px.data.iris()
gap = px.data.gapminder()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  species_id
# 0           5.1          3.5           1.4          0.2  setosa           1
# 1           4.9          3.0           1.4          0.2  setosa           1
# 2           4.7          3.2           1.3          0.2  setosa           1
# 3           4.6          3.1           1.5          0.2  setosa           1
# 4           5.0          3.6           1.4          0.2  setosa           1

# %%
gap.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %% [markdown]
# # Scatter Plot using plotly go

# %%
temp_df = gap[gap["year"] == 2007]
temp_df
# Out:
#                  country continent  year  lifeExp       pop     gdpPercap  \
# 11           Afghanistan      Asia  2007   43.828  31889923    974.580338
# 23               Albania    Europe  2007   76.423   3600523   5937.029526
# 35               Algeria    Africa  2007   72.301  33333216   6223.367465
# 47                Angola    Africa  2007   42.731  12420476   4797.231267
# 59             Argentina  Americas  2007   75.320  40301927  12779.379640
# ...                  ...       ...   ...      ...       ...           ...
# 1655             Vietnam      Asia  2007   74.249  85262356   2441.576404
# 1667  West Bank and Gaza      Asia  2007   73.422   4018332   3025.349798
# 1679         Yemen, Rep.      Asia  2007   62.698  22211743   2280.769906
# 1691              Zambia    Africa  2007   42.384  11746035   1271.211593
# 1703            Zimbabwe    Africa  2007   43.487  12311143    469.709298
#
#      iso_alpha  iso_num
# 11         AFG        4
# 23         ALB        8
# ...

# %%
trace1 = go.Scatter(x=temp_df["lifeExp"],y=temp_df["gdpPercap"])

data = [trace1]
layout = go.Layout(title="Life Exp VS GDP per Capita for 2007",xaxis={"title":"Life Exp"},yaxis={"title":"GDP"})
fig = go.Figure(data,layout)
fig.show("png")

# %%
trace1 = go.Scatter(x=temp_df["lifeExp"],y=temp_df["gdpPercap"],mode="markers")

data = [trace1]
layout = go.Layout(title="Life Exp VS GDP per Capita for 2007",xaxis={"title":"Life Exp"},yaxis={"title":"GDP"})
fig = go.Figure(data,layout)
fig.show("png")

# %%
trace1 = go.Scatter(x=temp_df["lifeExp"],y=temp_df["gdpPercap"],mode="markers")
trace2 = go.Scatter(x=[0,1,2],y=[0,90,30000],mode="lines")

data = [trace1,trace2]
layout = go.Layout(title="Life Exp VS GDP per Capita for 2007",xaxis={"title":"Life Exp"},yaxis={"title":"GDP"})
fig = go.Figure(data,layout)
fig.show("png")

# %% [markdown]
# ### Plot life exp and gdp scatter plot -> continent as color -> pop as size -> hover name

# %%
temp_df
# Out:
#                  country continent  year  lifeExp       pop     gdpPercap  \
# 11           Afghanistan      Asia  2007   43.828  31889923    974.580338
# 23               Albania    Europe  2007   76.423   3600523   5937.029526
# 35               Algeria    Africa  2007   72.301  33333216   6223.367465
# 47                Angola    Africa  2007   42.731  12420476   4797.231267
# 59             Argentina  Americas  2007   75.320  40301927  12779.379640
# ...                  ...       ...   ...      ...       ...           ...
# 1655             Vietnam      Asia  2007   74.249  85262356   2441.576404
# 1667  West Bank and Gaza      Asia  2007   73.422   4018332   3025.349798
# 1679         Yemen, Rep.      Asia  2007   62.698  22211743   2280.769906
# 1691              Zambia    Africa  2007   42.384  11746035   1271.211593
# 1703            Zimbabwe    Africa  2007   43.487  12311143    469.709298
#
#      iso_alpha  iso_num
# 11         AFG        4
# 23         ALB        8
# ...

# %%
fig = px.scatter(temp_df,x="lifeExp",y="gdpPercap")
fig.show("png")

# %%
fig = px.scatter(temp_df,x="lifeExp",y="gdpPercap",color="continent")
fig.show("png")

# %%
fig = px.scatter(temp_df,x="lifeExp",y="gdpPercap",color="continent",size="pop")
fig.show("png")

# %%
fig = px.scatter(temp_df,x="lifeExp",y="gdpPercap",color="continent",size="pop",size_max=100)
fig.show("png")

# %%
fig = px.scatter(temp_df,x="lifeExp",y="gdpPercap",color="continent",size="pop",size_max=100,hover_name="country")
fig.show("png")

# %% [markdown]
# ### Plot animation of the above curve on the basic of year

# %%
gap
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
fig = px.scatter(gap,x="lifeExp",y="gdpPercap",
           color="continent",size="pop",
           size_max=100,hover_name="country",
          animation_frame="year",animation_group="country")
fig.show("png")

# %%
fig = px.scatter(gap,x="lifeExp",y="gdpPercap",
           color="continent",size="pop",
           size_max=100,hover_name="country",
           range_x = [30,95],
          animation_frame="year",animation_group="country")
fig.show("png")

# %% [markdown]
# # Line Plot

# %% [markdown]
# ### Plot India population line plot

# %%
temp_df = gap[gap["country"] == "India"]
temp_df
# Out:
#     country continent  year  lifeExp         pop    gdpPercap iso_alpha  \
# 696   India      Asia  1952   37.373   372000000   546.565749       IND
# 697   India      Asia  1957   40.249   409000000   590.061996       IND
# 698   India      Asia  1962   43.605   454000000   658.347151       IND
# 699   India      Asia  1967   47.193   506000000   700.770611       IND
# 700   India      Asia  1972   50.651   567000000   724.032527       IND
# 701   India      Asia  1977   54.208   634000000   813.337323       IND
# 702   India      Asia  1982   56.596   708000000   855.723538       IND
# 703   India      Asia  1987   58.553   788000000   976.512676       IND
# 704   India      Asia  1992   60.223   872000000  1164.406809       IND
# 705   India      Asia  1997   61.765   959000000  1458.817442       IND
# 706   India      Asia  2002   62.879  1034172547  1746.769454       IND
# 707   India      Asia  2007   64.698  1110396331  2452.210407       IND
#
#      iso_num
# 696      356
# ...

# %%
fig = px.line(temp_df,x="year",y="pop")
fig.show("png")

# %%
fig = px.line(temp_df,x="year",y="pop",title="India Population Growth")
fig.show("png")

# %% [markdown]
# ### Plot India, China ,Pak LifeExp line plot

# %%
temp_df = gap[gap["country"].isin(["India","China","Pakistan"])]
temp_df
# Out:
#        country continent  year   lifeExp         pop    gdpPercap iso_alpha  \
# 288      China      Asia  1952  44.00000   556263527   400.448611       CHN
# 289      China      Asia  1957  50.54896   637408000   575.987001       CHN
# 290      China      Asia  1962  44.50136   665770000   487.674018       CHN
# 291      China      Asia  1967  58.38112   754550000   612.705693       CHN
# 292      China      Asia  1972  63.11888   862030000   676.900092       CHN
# 293      China      Asia  1977  63.96736   943455000   741.237470       CHN
# 294      China      Asia  1982  65.52500  1000281000   962.421380       CHN
# 295      China      Asia  1987  67.27400  1084035000  1378.904018       CHN
# 296      China      Asia  1992  68.69000  1164970000  1655.784158       CHN
# 297      China      Asia  1997  70.42600  1230075000  2289.234136       CHN
# 298      China      Asia  2002  72.02800  1280400000  3119.280896       CHN
# ...

# %%
temp_df = temp_df.pivot(index="year",columns="country",values="lifeExp")
temp_df
# Out:
# country     China   India  Pakistan
# year
# 1952     44.00000  37.373    43.436
# 1957     50.54896  40.249    45.557
# 1962     44.50136  43.605    47.670
# 1967     58.38112  47.193    49.800
# 1972     63.11888  50.651    51.929
# 1977     63.96736  54.208    54.043
# 1982     65.52500  56.596    56.158
# 1987     67.27400  58.553    58.245
# 1992     68.69000  60.223    60.838
# 1997     70.42600  61.765    61.818
# 2002     72.02800  62.879    63.610
# 2007     72.96100  64.698    65.483

# %%
fig = px.line(temp_df,x=temp_df.index,y=temp_df.columns)
fig.show("png")

# %% [markdown]
# # Bar Chart

# %% [markdown]
# ### India's pop over the years

# %%
temp_df = gap[gap["country"] == "India"]
temp_df
# Out:
#     country continent  year  lifeExp         pop    gdpPercap iso_alpha  \
# 696   India      Asia  1952   37.373   372000000   546.565749       IND
# 697   India      Asia  1957   40.249   409000000   590.061996       IND
# 698   India      Asia  1962   43.605   454000000   658.347151       IND
# 699   India      Asia  1967   47.193   506000000   700.770611       IND
# 700   India      Asia  1972   50.651   567000000   724.032527       IND
# 701   India      Asia  1977   54.208   634000000   813.337323       IND
# 702   India      Asia  1982   56.596   708000000   855.723538       IND
# 703   India      Asia  1987   58.553   788000000   976.512676       IND
# 704   India      Asia  1992   60.223   872000000  1164.406809       IND
# 705   India      Asia  1997   61.765   959000000  1458.817442       IND
# 706   India      Asia  2002   62.879  1034172547  1746.769454       IND
# 707   India      Asia  2007   64.698  1110396331  2452.210407       IND
#
#      iso_num
# 696      356
# ...

# %%
fig = px.bar(temp_df,x="year",y="pop")
fig.show("png")

# %% [markdown]
# ### gdpPercap comp of 3 countries

# %%
temp_df = gap[gap["country"].isin(["India","China","Pakistan"])]
temp_df
# Out:
#        country continent  year   lifeExp         pop    gdpPercap iso_alpha  \
# 288      China      Asia  1952  44.00000   556263527   400.448611       CHN
# 289      China      Asia  1957  50.54896   637408000   575.987001       CHN
# 290      China      Asia  1962  44.50136   665770000   487.674018       CHN
# 291      China      Asia  1967  58.38112   754550000   612.705693       CHN
# 292      China      Asia  1972  63.11888   862030000   676.900092       CHN
# 293      China      Asia  1977  63.96736   943455000   741.237470       CHN
# 294      China      Asia  1982  65.52500  1000281000   962.421380       CHN
# 295      China      Asia  1987  67.27400  1084035000  1378.904018       CHN
# 296      China      Asia  1992  68.69000  1164970000  1655.784158       CHN
# 297      China      Asia  1997  70.42600  1230075000  2289.234136       CHN
# 298      China      Asia  2002  72.02800  1280400000  3119.280896       CHN
# ...

# %%
temp_df = temp_df.pivot(index="year",columns="country",values="gdpPercap")
temp_df
# Out:
# country        China        India     Pakistan
# year
# 1952      400.448611   546.565749   684.597144
# 1957      575.987001   590.061996   747.083529
# 1962      487.674018   658.347151   803.342742
# 1967      612.705693   700.770611   942.408259
# 1972      676.900092   724.032527  1049.938981
# 1977      741.237470   813.337323  1175.921193
# 1982      962.421380   855.723538  1443.429832
# 1987     1378.904018   976.512676  1704.686583
# 1992     1655.784158  1164.406809  1971.829464
# 1997     2289.234136  1458.817442  2049.350521
# 2002     3119.280896  1746.769454  2092.712441
# 2007     4959.114854  2452.210407  2605.947580

# %% [markdown]
# # Grouped Bar Chart

# %%
fig = px.bar(temp_df,x=temp_df.index,y=temp_df.columns,barmode="group")
fig.show("png")

# %% [markdown]
# # Stacked Bar Chart

# %%
fig = px.bar(temp_df,x=temp_df.index,y=temp_df.columns,text_auto=True)
fig.show("png")

# %% [markdown]
# ### Using log_y parameter

# %%
temp_df = gap[gap["country"].isin(["India","China","Pakistan"])]
temp_df
# Out:
#        country continent  year   lifeExp         pop    gdpPercap iso_alpha  \
# 288      China      Asia  1952  44.00000   556263527   400.448611       CHN
# 289      China      Asia  1957  50.54896   637408000   575.987001       CHN
# 290      China      Asia  1962  44.50136   665770000   487.674018       CHN
# 291      China      Asia  1967  58.38112   754550000   612.705693       CHN
# 292      China      Asia  1972  63.11888   862030000   676.900092       CHN
# 293      China      Asia  1977  63.96736   943455000   741.237470       CHN
# 294      China      Asia  1982  65.52500  1000281000   962.421380       CHN
# 295      China      Asia  1987  67.27400  1084035000  1378.904018       CHN
# 296      China      Asia  1992  68.69000  1164970000  1655.784158       CHN
# 297      China      Asia  1997  70.42600  1230075000  2289.234136       CHN
# 298      China      Asia  2002  72.02800  1280400000  3119.280896       CHN
# ...

# %%
temp_df = temp_df.pivot(index="year",columns="country",values="pop")
temp_df
# Out:
# country       China       India   Pakistan
# year
# 1952      556263527   372000000   41346560
# 1957      637408000   409000000   46679944
# 1962      665770000   454000000   53100671
# 1967      754550000   506000000   60641899
# 1972      862030000   567000000   69325921
# 1977      943455000   634000000   78152686
# 1982     1000281000   708000000   91462088
# 1987     1084035000   788000000  105186881
# 1992     1164970000   872000000  120065004
# 1997     1230075000   959000000  135564834
# 2002     1280400000  1034172547  153403524
# 2007     1318683096  1110396331  169270617

# %%
fig = px.bar(temp_df,x=temp_df.index,y=temp_df.columns,barmode="group",log_y=True)
fig.show("png")

# %% [markdown]
# ### pop contribution per country to a continents pop stacked for a particular year(2007)

# %%
temp_df = gap[gap["year"] == 2007]
temp_df
# Out:
#                  country continent  year  lifeExp       pop     gdpPercap  \
# 11           Afghanistan      Asia  2007   43.828  31889923    974.580338
# 23               Albania    Europe  2007   76.423   3600523   5937.029526
# 35               Algeria    Africa  2007   72.301  33333216   6223.367465
# 47                Angola    Africa  2007   42.731  12420476   4797.231267
# 59             Argentina  Americas  2007   75.320  40301927  12779.379640
# ...                  ...       ...   ...      ...       ...           ...
# 1655             Vietnam      Asia  2007   74.249  85262356   2441.576404
# 1667  West Bank and Gaza      Asia  2007   73.422   4018332   3025.349798
# 1679         Yemen, Rep.      Asia  2007   62.698  22211743   2280.769906
# 1691              Zambia    Africa  2007   42.384  11746035   1271.211593
# 1703            Zimbabwe    Africa  2007   43.487  12311143    469.709298
#
#      iso_alpha  iso_num
# 11         AFG        4
# 23         ALB        8
# ...

# %%
fig = px.bar(temp_df,x="continent",y="pop",color="country")
fig.show("png")

# %%
fig = px.bar(temp_df,x="continent",y="pop",color="country",log_y=True)
fig.show("png")

# %% [markdown]
# ### bar chart animation

# %%
gap
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
fig = px.bar(gap,x="continent",y="pop",color="continent",
       animation_frame="year",animation_group="country")
fig.show("png")

# %%
fig = px.bar(gap,x="continent",y="pop",color="continent",
       animation_frame="year",animation_group="country",range_y=[0,4000000000])
fig.show("png")

# %% [markdown]
# # Histogram

# %% [markdown]
# ### Plot histogram of life expt of all countries in 2007 -> nbins -> text_auto

# %%
temp_df = gap[gap["year"] == 2007]
temp_df
# Out:
#                  country continent  year  lifeExp       pop     gdpPercap  \
# 11           Afghanistan      Asia  2007   43.828  31889923    974.580338
# 23               Albania    Europe  2007   76.423   3600523   5937.029526
# 35               Algeria    Africa  2007   72.301  33333216   6223.367465
# 47                Angola    Africa  2007   42.731  12420476   4797.231267
# 59             Argentina  Americas  2007   75.320  40301927  12779.379640
# ...                  ...       ...   ...      ...       ...           ...
# 1655             Vietnam      Asia  2007   74.249  85262356   2441.576404
# 1667  West Bank and Gaza      Asia  2007   73.422   4018332   3025.349798
# 1679         Yemen, Rep.      Asia  2007   62.698  22211743   2280.769906
# 1691              Zambia    Africa  2007   42.384  11746035   1271.211593
# 1703            Zimbabwe    Africa  2007   43.487  12311143    469.709298
#
#      iso_alpha  iso_num
# 11         AFG        4
# 23         ALB        8
# ...

# %%
fig = px.histogram(temp_df,x="lifeExp",text_auto=True)
fig.show("png")

# %%
fig = px.histogram(temp_df,x="lifeExp",text_auto=True,nbins=10)
fig.show("png")

# %% [markdown]
# ### Plot histogram of sepal length of all iris species

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# ...

# %%
fig = px.histogram(iris,x="sepal_length",text_auto=True)
fig.show("png")

# %%
fig = px.histogram(iris,x="sepal_length",text_auto=True,color="species")
fig.show("png")

# %% [markdown]
# # Pie Chart

# %% [markdown]
# ### Find the pie chart of pop of european countries in 2007

# %%
temp_df = gap[(gap["year"] == 2007) & (gap["continent"]=="Europe")]
temp_df
# Out:
#                      country continent  year  lifeExp       pop     gdpPercap  \
# 23                   Albania    Europe  2007   76.423   3600523   5937.029526
# 83                   Austria    Europe  2007   79.829   8199783  36126.492700
# 119                  Belgium    Europe  2007   79.441  10392226  33692.605080
# 155   Bosnia and Herzegovina    Europe  2007   74.852   4552198   7446.298803
# 191                 Bulgaria    Europe  2007   73.005   7322858  10680.792820
# 383                  Croatia    Europe  2007   75.748   4493312  14619.222720
# 407           Czech Republic    Europe  2007   76.486  10228744  22833.308510
# 419                  Denmark    Europe  2007   78.332   5468120  35278.418740
# 527                  Finland    Europe  2007   79.313   5238460  33207.084400
# 539                   France    Europe  2007   80.657  61083916  30470.016700
# 575                  Germany    Europe  2007   79.406  82400996  32170.374420
# ...

# %%
fig = px.pie(temp_df,names="country",values="pop")
fig.show("png")

# %% [markdown]
# ### plot pie chart of world pop in 1952 continent wise  -> explode(pull)

# %%
temp_df = gap[gap["year"] == 1952].groupby("continent")["pop"].sum().reset_index()
temp_df
# Out:
#   continent         pop
# 0    Africa   237640501
# 1  Americas   345152446
# 2      Asia  1395357351
# 3    Europe   418120846
# 4   Oceania    10686006

# %%
fig = px.pie(temp_df,names="continent",values="pop")
fig.show("png")

# %% [markdown]
# ### Sunburst plot : Sunburst plots visualize hierarchical data spanning outwards radially from root to leaves.

# %%
temp_df = gap[gap["year"] == 2007]
temp_df
# Out:
#                  country continent  year  lifeExp       pop     gdpPercap  \
# 11           Afghanistan      Asia  2007   43.828  31889923    974.580338
# 23               Albania    Europe  2007   76.423   3600523   5937.029526
# 35               Algeria    Africa  2007   72.301  33333216   6223.367465
# 47                Angola    Africa  2007   42.731  12420476   4797.231267
# 59             Argentina  Americas  2007   75.320  40301927  12779.379640
# ...                  ...       ...   ...      ...       ...           ...
# 1655             Vietnam      Asia  2007   74.249  85262356   2441.576404
# 1667  West Bank and Gaza      Asia  2007   73.422   4018332   3025.349798
# 1679         Yemen, Rep.      Asia  2007   62.698  22211743   2280.769906
# 1691              Zambia    Africa  2007   42.384  11746035   1271.211593
# 1703            Zimbabwe    Africa  2007   43.487  12311143    469.709298
#
#      iso_alpha  iso_num
# 11         AFG        4
# 23         ALB        8
# ...

# %%
fig = px.sunburst(temp_df,path=["continent","country"],values="pop")
fig.show("png")

# %%
fig = px.sunburst(temp_df,path=["continent","country"],values="pop",color="lifeExp")
fig.show("png")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
fig = px.sunburst(tips,path=["sex","smoker","day","time"],values="total_bill",color="size")
fig.show("png")

# %% [markdown]
# # TreeMap

# %%
temp_df = gap[gap["year"] == 2007]
temp_df
# Out:
#                  country continent  year  lifeExp       pop     gdpPercap  \
# 11           Afghanistan      Asia  2007   43.828  31889923    974.580338
# 23               Albania    Europe  2007   76.423   3600523   5937.029526
# 35               Algeria    Africa  2007   72.301  33333216   6223.367465
# 47                Angola    Africa  2007   42.731  12420476   4797.231267
# 59             Argentina  Americas  2007   75.320  40301927  12779.379640
# ...                  ...       ...   ...      ...       ...           ...
# 1655             Vietnam      Asia  2007   74.249  85262356   2441.576404
# 1667  West Bank and Gaza      Asia  2007   73.422   4018332   3025.349798
# 1679         Yemen, Rep.      Asia  2007   62.698  22211743   2280.769906
# 1691              Zambia    Africa  2007   42.384  11746035   1271.211593
# 1703            Zimbabwe    Africa  2007   43.487  12311143    469.709298
#
#      iso_alpha  iso_num
# 11         AFG        4
# 23         ALB        8
# ...

# %%
fig = px.treemap(temp_df,path=[px.Constant("World"),"continent","country"],values="pop",color="lifeExp")
fig.show("png")

# %% [markdown]
# # Heatmap

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
temp_df = tips.pivot_table(index="day",columns="sex",values="total_bill",aggfunc="sum")
temp_df
# Out:
# sex   Female     Male
# day
# Fri   127.31   198.57
# Sat   551.05  1227.35
# Sun   357.70  1269.46
# Thur  534.89   561.44

# %%
fig = px.imshow(temp_df)
fig.show("png")

# %% [markdown]
# ### find heatmap of all continents with year on avg life exp

# %%
temp_df = gap.pivot_table(index="year",columns="continent",values="lifeExp",aggfunc="mean")
temp_df
# Out:
# continent     Africa  Americas       Asia     Europe  Oceania
# year
# 1952       39.135500  53.27984  46.314394  64.408500  69.2550
# 1957       41.266346  55.96028  49.318544  66.703067  70.2950
# 1962       43.319442  58.39876  51.563223  68.539233  71.0850
# 1967       45.334538  60.41092  54.663640  69.737600  71.3100
# 1972       47.450942  62.39492  57.319269  70.775033  71.9100
# 1977       49.580423  64.39156  59.610556  71.937767  72.8550
# 1982       51.592865  66.22884  62.617939  72.806400  74.2900
# 1987       53.344788  68.09072  64.851182  73.642167  75.3200
# 1992       53.629577  69.56836  66.537212  74.440100  76.9450
# 1997       53.598269  71.15048  68.020515  75.505167  78.1900
# 2002       53.325231  72.42204  69.233879  76.700600  79.7400
# 2007       54.806038  73.60812  70.728485  77.648600  80.7195

# %%
fig = px.imshow(temp_df)
fig.show("png")

# %% [markdown]
# # 3D Scatterplot

# %% [markdown]
# ### plot a 3d scatter plot of all country data for 2007

# %%
temp_df = gap[gap["year"] == 2007]
temp_df
# Out:
#                  country continent  year  lifeExp       pop     gdpPercap  \
# 11           Afghanistan      Asia  2007   43.828  31889923    974.580338
# 23               Albania    Europe  2007   76.423   3600523   5937.029526
# 35               Algeria    Africa  2007   72.301  33333216   6223.367465
# 47                Angola    Africa  2007   42.731  12420476   4797.231267
# 59             Argentina  Americas  2007   75.320  40301927  12779.379640
# ...                  ...       ...   ...      ...       ...           ...
# 1655             Vietnam      Asia  2007   74.249  85262356   2441.576404
# 1667  West Bank and Gaza      Asia  2007   73.422   4018332   3025.349798
# 1679         Yemen, Rep.      Asia  2007   62.698  22211743   2280.769906
# 1691              Zambia    Africa  2007   42.384  11746035   1271.211593
# 1703            Zimbabwe    Africa  2007   43.487  12311143    469.709298
#
#      iso_alpha  iso_num
# 11         AFG        4
# 23         ALB        8
# ...

# %%
fig = px.scatter_3d(temp_df,x="lifeExp",y="pop",z="gdpPercap")
fig.show("png")

# %%
fig = px.scatter_3d(temp_df,x="lifeExp",y="pop",z="gdpPercap",log_y=True)
fig.show("png")

# %%
fig = px.scatter_3d(temp_df,x="lifeExp",y="pop",z="gdpPercap",log_y=True,color="continent")
fig.show("png")

# %%
fig = px.scatter_3d(temp_df,x="lifeExp",y="pop",z="gdpPercap",log_y=True,color="continent",hover_name="country")
fig.show("png")

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# ...

# %%
fig = px.scatter_3d(iris,x="sepal_length",y="sepal_width",z="petal_length")
fig.show("png")

# %%
fig = px.scatter_3d(iris,x="sepal_length",y="sepal_width",z="petal_length",color="species")
fig.show("png")

# %% [markdown]
# # Scatter_matrix

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# ...

# %%
fig = px.scatter_matrix(iris,dimensions=iris.columns[:-2])
fig.show("png")

# %%
fig = px.scatter_matrix(iris,dimensions=iris.columns[:-2],color="species")
fig.show("png")

# %% [markdown]
# ### Facet_grid

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
fig = px.scatter(tips,x="total_bill",y="tip",facet_col="sex")
fig.show("png")

# %%
fig = px.scatter(tips,x="total_bill",y="tip",facet_col="day")
fig.show("png")

# %%
fig = px.scatter(tips,x="total_bill",y="tip",facet_col="smoker")
fig.show("png")

# %%
fig = px.scatter(tips,x="total_bill",y="tip",facet_col="smoker",facet_row="sex")
fig.show("png")

# %%
fig = px.histogram(tips,x="total_bill",facet_col="sex")
fig.show("png")

# %%
fig = px.histogram(tips,x="total_bill",facet_col="smoker")
fig.show("png")

# %%
fig = px.histogram(tips,x="total_bill",facet_row="smoker")
fig.show("png")

# %%
gap.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
fig = px.scatter(gap,x="lifeExp",y="gdpPercap")
fig.show("png")

# %%
fig = px.scatter(gap,x="lifeExp",y="gdpPercap",facet_col="year",facet_col_wrap=4,color="continent")
fig.show("png")

# %% [markdown]
# ### 3D Surface Plot
#
# - cannot be created using plotly express

# %%
x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)

xx, yy = np.meshgrid(x,y)

z = xx**2 + yy**2

trace = go.Surface(x=x,y=y,z=z)

data = [trace]

layout = go.Layout(title='3D Surface Plot')

fig = go.Figure(data,layout)

fig.show("png")

# %%
x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)

xx, yy = np.meshgrid(x,y)

z = np.sin(xx) + np.cos(yy)

trace = go.Surface(x=x,y=y,z=z)

data = [trace]

layout = go.Layout(title='3D Surface Plot')

fig = go.Figure(data,layout)

fig.show("png")

# %%
x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)

xx, yy = np.meshgrid(x,y)

z = np.sin(xx) + np.tan(yy)

trace = go.Surface(x=x,y=y,z=z)

data = [trace]

layout = go.Layout(title='3D Surface Plot')

fig = go.Figure(data,layout)

fig.show("png")

# %%
x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)

xx, yy = np.meshgrid(x,y)
z = np.sqrt(xx**2 + yy**2)


trace = go.Surface(x=x,y=y,z=z)

data = [trace]

layout = go.Layout(title='3D Surface Plot')

fig = go.Figure(data,layout)

fig.show("png")

# %% [markdown]
# ### Contour Plot

# %%
x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)

xx, yy = np.meshgrid(x,y)
z = np.sqrt(xx**2 + yy**2)


trace = go.Contour(x=x,y=y,z=z)

data = [trace]

layout = go.Layout(title='3D Surface Plot')

fig = go.Figure(data,layout)

fig.show("png")

# %%
x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)

xx, yy = np.meshgrid(x,y)

z = np.sin(xx) + np.cos(yy)

trace = go.Contour(x=x,y=y,z=z)

data = [trace]

layout = go.Layout(title='3D Surface Plot')

fig = go.Figure(data,layout)

fig.show("png")

# %% [markdown]
# ### Subplots

# %%
from plotly.subplots import make_subplots

# %%
fig = make_subplots(rows=1,cols=2)

# %%
fig.add_trace(
    go.Scatter(x=[1,9,5],y=[2,10,1]),
    row=1,
    col=1
)

fig.add_trace(
    go.Histogram(x=[1,9,5,5,5]),
    row=1,
    col=2
)

fig.update_layout(title="subplot demo")
fig.show("png")

# %%
fig = make_subplots(rows=2,cols=2)

# %%
fig.add_trace(
    go.Scatter(x=[1,9,5],y=[2,10,1]),
    row=1,
    col=1
)

fig.add_trace(
    go.Histogram(x=[1,9,5,5,5]),
    row=1,
    col=2
)

fig.add_trace(
    go.Scatter(x=[1,9,5],y=[2,10,1],mode="markers"),
    row=2,
    col=1
)

fig.add_trace(
    go.Histogram(x=[1,9,5,5,5,10,11,12,13]),
    row=2,
    col=2
)


fig.update_layout(title="subplot demo")
fig.show("png")
